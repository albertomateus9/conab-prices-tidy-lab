# %% [markdown]
# # Laboratorio CONAB De Precos E Tidy Data
#
# Transformacao de tabelas wide para long e calculo de variacao percentual em precos sinteticos.
#
# Este notebook registra uma exploração leve sobre amostras seguras e reprodutíveis.

# %%
from pathlib import Path
ROOT = Path.cwd().parents[0]
print("Notebook didático pronto para execução local.")
